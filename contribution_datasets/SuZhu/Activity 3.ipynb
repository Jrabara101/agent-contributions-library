# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
web = 'https://en.wikipedia.org/wiki/Three_Arrows_Capital'
response = requests.get(web).text
soup = bs(response,'lxml')

# %%
blocks = soup.find_all('p')

# %%
contents = []

for content in blocks:
    contents.append(content.text)

# %%
joined_contents = ' '.join(contents)

# %%
sentence_endings = [".", "!", "?"]
sentences = []

start = 0
for i, char in enumerate(joined_contents):
    if char in sentence_endings:
        # Include the punctuation mark with the sentence
        sentences.append(joined_contents[start:i+1].strip())
        start = i + 1  # Move past the punctuation mark

#Group the sentences into chunks of 2
chunks = [" ".join(sentences[i:i+2]) for i in range(0, len(sentences), 2)]

# %%
cz_keywords = [
    "Three Arrows Capital", 
    "History", 
    "Licensing and regulatory issues", 
    "Liquidation", 
    "OPNX", 
    "Arrest of Su Zhu"
]

# %%
# Function to find keywords in a sentence
def find_keywords(sentence, keywords):
    return [keyword for keyword in keywords if keyword.lower() in sentence.lower()]

# Function to replace empty keyword lists with 'other'
def process_keywords(keywords):
    return ', '.join(keywords) if keywords else "other"

# %%
data = {'contents':[],'keywords':[]}

# Process each sentence
for sentence in chunks:
    found_keywords = find_keywords(sentence, cz_keywords)
    data['contents'].append(sentence)
    data['keywords'].append(process_keywords(found_keywords))

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                              contents  \
# 0   Three Arrows Capital (also known as 3AC or TAC...
# 1   [3][4][5] The company borrowed billions of dol...
# 2   [6][7] The fund appears to have lost in excess...
# 3   [8][9] In its early years, the company was foc...
# 4   This practice continued until banks started to...
# 5   [11] Blockchain analytics firm Nansen estimate...
# 6   Su Zhu had more than 500,000 followers shortly...
# 7   [17] According to a January 2021 SEC filing, T...
# 8   [4][19][20]\n In April 2022 Bloomberg reported...
# 9   [22]\n Cryptocurrencies experienced broad decl...
# 10  [25] The spread between Grayscale GBTC trust u...
# 11                     TerraForm Labs Pte Ltd. et al.
# 12  , was filed against Three Arrows and others in...
# 13  [citation needed]\n On 30 June 2022, the Monet...
# 14  [28]\n In October 2022, it was reported that T...
# 15  Securities and Exchange Commission and the Con...
# 16  [30] On 22 June, The Wall Street Journal repor...
# 17  [32] On the same day, a court in the British V...
# 18  [1][33][34]\n On 2 July 2022, Three Arrows fil...
# 19  [36]\n Genesis Trading's CEO Michael Moro anno...
# 20  com. FTX founder and CEO Sam Bankman-Fried bla...
# 21  [38][10]\n According to court liquidation pape...
# 22  5 billion. [40]\n In an interview with Bloombe...
# 23  [citation needed]\n According to the New York ...
# 24  It's home to ducks, chickens and numerous type...
# 25  "[42]\n In June 2023, Three Arrows liquidators...
# 26  [43]\n In late 2022, Zhu and Davies started an...
# 27                                                . .
# 28  Nothing compares to the energy of a startup. "...
# 29  [46] Zhu was arrested pursuant to committal or...
#
#                              keywords
# 0                Three Arrows Capital
# 1                               other
# 2                               other
# 3                               other
# 4                               other
# 5                               other
# 6                               other
# 7                               other
# 8                               other
# 9                               other
# 10                              other
# 11                              other
# 12                              other
# 13                              other
# 14               Three Arrows Capital
# 15                              other
# 16                              other
# 17  Three Arrows Capital, Liquidation
# 18                              other
# 19                              other
# 20                              other
# 21  Three Arrows Capital, Liquidation
# 22                              other
# 23                        Liquidation
# 24               Three Arrows Capital
# 25                              other
# 26                              other
# 27                              other
# 28                              other
# 29                              other

# %%
# save to txt 
df.to_csv('cz1.txt',index=None, sep='\t')

#create branch and make a pull request
